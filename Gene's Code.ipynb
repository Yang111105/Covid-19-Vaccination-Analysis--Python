# %%
import pandas as pd

# %%
file1 = "Resource/01_vaccine_us_county.csv"
file2 = "Resource/02_us_county_sociohealth_data.csv"

# %%
Us_county_df1 = pd.read_csv(file1)
Us_county_df1
# Out:
#             Date   FIPS  MMWR_week        Recip_County Recip_State  \
# 0     09/30/2021  49057         39        Weber County          UT
# 1     09/30/2021  15007         39        Kauai County          HI
# 2     09/30/2021  16027         39       Canyon County          ID
# 3     09/30/2021  18171         39       Warren County          IN
# 4     09/30/2021  27007         39     Beltrami County          MN
# ...          ...    ...        ...                 ...         ...
# 3277  09/30/2021  06019         39       Fresno County          CA
# 3278  09/30/2021  31149         39         Rock County          NE
# 3279  09/30/2021  23021         39  Piscataquis County          ME
# 3280  09/30/2021  40101         39     Muskogee County          OK
# 3281  09/30/2021  31027         39        Cedar County          NE
#
#       Series_Complete_Pop_Pct  Series_Complete_Yes  Series_Complete_12Plus  \
# 0                        47.1               122652                122646.0
# ...

# %%
sociohealth_df2 = pd.read_csv(file2)

sociohealth_df2 = sociohealth_df2.rename(columns={"fips": "FIPS"})

sociohealth_df3 = sociohealth_df2[["FIPS","total_population","county","state","percentile_rank_minorities"]]

sociohealth_df3
# Out:
#       total_population         county     state  percentile_rank_minorities
# 0                55049        Autauga   Alabama                    0.633900
# 1               199510        Baldwin   Alabama                    0.525300
# 2                26614        Barbour   Alabama                    0.904200
# 3                22572           Bibb   Alabama                    0.645000
# 4                57704         Blount   Alabama                    0.423800
# ...                ...            ...       ...                         ...
# 3139             20893          Uinta   Wyoming                    0.421200
# 3140              8351       Washakie   Wyoming                    0.536100
# 3141              7175         Weston   Wyoming                    0.288800
# 3142           1113072    Kansas City  Missouri                    0.675575
# 3143           8461961  New York City  New York                    0.945408
#
# [3144 rows x 4 columns]

# %%
merged_df = pd.merge(Us_county_df1,sociohealth_df2, on='FIPS')
merged_df
# Out:
#             Date   FIPS  MMWR_week        Recip_County Recip_State  \
# 0     09/30/2021  49057         39        Weber County          UT
# 1     09/30/2021  15007         39        Kauai County          HI
# 2     09/30/2021  16027         39       Canyon County          ID
# 3     09/30/2021  18171         39       Warren County          IN
# 4     09/30/2021  27007         39     Beltrami County          MN
# ...          ...    ...        ...                 ...         ...
# 3137  09/30/2021  06019         39       Fresno County          CA
# 3138  09/30/2021  31149         39         Rock County          NE
# 3139  09/30/2021  23021         39  Piscataquis County          ME
# 3140  09/30/2021  40101         39     Muskogee County          OK
# 3141  09/30/2021  31027         39        Cedar County          NE
#
#       Series_Complete_Pop_Pct  Series_Complete_Yes  Series_Complete_12Plus  \
# 0                        47.1               122652                122646.0
# ...

# %%
print(merged_df.columns)
# Out:
# Index(['Date', 'FIPS', 'MMWR_week', 'Recip_County', 'Recip_State',
#        'Series_Complete_Pop_Pct', 'Series_Complete_Yes',
#        'Series_Complete_12Plus', 'Series_Complete_12PlusPop_Pct',
#        'Series_Complete_18Plus',
#        ...
#        'percentile_rank_minorities',
#        'percentile_rank_limited_english_abilities',
#        'percentile_rank_minority_status_and_language_theme',
#        'percentile_rank_multi_unit_housing', 'percentile_rank_mobile_homes',
#        'percentile_rank_overcrowding', 'percentile_rank_no_vehicle',
#        'percentile_rank_institutionalized_in_group_quarters',
#        'percentile_rank_housing_and_transportation',
#        'percentile_rank_social_vulnerability'],
#       dtype='object', length=212)

# %%
merged_df.plot
